# %% [markdown]
# # Visualization for Maxwell 1D Task

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 800
num_threads = 32
length_factor = 10
# !ssh Vladislav.Lukoshkin@10.30.17.12 "export OMP_NUM_THREADS={num_threads}" 2> /dev/null
# !ssh Vladislav.Lukoshkin@10.30.17.12 "cd HPC; c++ maxwell.cpp -fopenmp; ./a.out {length_factor} {N}" 2> /dev/null
# Out:
# time spent on bc initialization : 0.001806s
# time spent on filling the sol. array : 0.000s

# %%
# !scp Vladislav.Lukoshkin@10.30.17.12:HPC/output.bin . 2> /dev/null
# Out:
# output.bin                                    100% 2500KB   7.0MB/s   00:00

# %%
data = np.fromfile("output.bin", dtype=np.float32)
data.shape
# Out:
# (640000,)

# %%
plt.plot(data[:100]);

# %%
plt.imshow(data.reshape(N,N)[::-1]);
